# %%
import random
from collections import defaultdict

# %%
# Initialize parameters
classes = ['class1', 'class2', 'class3', 'class4', 'class5', 'class6', 'class7', 'class8', 'class10', 'class10_1', ]
num_classes = len(classes)
total_images = 100
target_per_class = 150  # Total number of items per class
max_items_per_class_per_image = 2  # Maximum number of items per class per image

# %%
# Class counters to track how many items per class have been assigned
class_counters = {class_name: 0 for class_name in classes}

# Dictionary to store how many items of each class are in each image
image_class_distribution = defaultdict(lambda: {class_name: 0 for class_name in classes})

# %%
# Distribute items across images
for image_idx in range(total_images):
    for class_name in classes:
        # Determine the remaining items needed for this class to meet the target
        remaining_items_for_class = target_per_class - class_counters[class_name]

        if remaining_items_for_class > 0:
            # Choose between 1 and 2 items, but do not exceed the remaining target for the class
            num_items = random.choice([1, 2])
            num_items = min(num_items, remaining_items_for_class)

            # Update class counter and record the number of items for this image
            class_counters[class_name] += num_items
            image_class_distribution[image_idx][class_name] = num_items

# %%
# Print result of the distribution
for image_idx in range(total_images):
    print(f"Image {image_idx + 1}: {image_class_distribution[image_idx]}")
# Out:
# Image 1: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 2: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 3: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 4: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 5: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 6: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 7: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 8: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 9: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 10: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 11: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 12: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 13: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 14: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 15: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 16: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 17: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 18: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 19: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 20: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 21: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 22: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 23: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 24: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 25: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 26: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 27: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 28: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 29: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 30: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 31: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 32: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 33: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 34: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 35: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 36: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 37: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 38: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 39: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 40: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 41: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 42: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 43: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 44: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 45: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 46: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 47: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 48: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 49: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 50: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 51: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 52: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 53: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 54: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 55: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 56: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 57: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 58: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 59: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 60: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 61: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 62: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 63: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 64: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 65: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 66: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 67: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 68: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 69: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 70: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 71: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 72: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 73: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 74: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 75: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 76: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 77: {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 78: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 79: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 80: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 81: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 82: {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 83: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 84: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 85: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 86: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2}
# Image 87: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2}
# Image 88: {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2}
# Image 89: {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 90: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 91: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 92: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2}
# Image 93: {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 1}
# Image 94: {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1}
# Image 95: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1}
# Image 96: {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1}
# Image 97: {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 0}
# Image 98: {'class1': 1, 'class2': 1, 'class3': 0, 'class4': 1, 'class5': 0, 'class6': 2, 'class7': 0, 'class8': 2, 'class10': 2, 'class10_1': 0}
# Image 99: {'class1': 0, 'class2': 0, 'class3': 0, 'class4': 1, 'class5': 0, 'class6': 1, 'class7': 0, 'class8': 1, 'class10': 2, 'class10_1': 0}
# Image 100: {'class1': 0, 'class2': 0, 'class3': 0, 'class4': 1, 'class5': 0, 'class6': 1, 'class7': 0, 'class8': 1, 'class10': 1, 'class10_1': 0}

# %%
# Check class balance
print("\nTotal items per class:")
for class_name in classes:
    total_items_for_class = sum(image_class_distribution[image_idx][class_name] for image_idx in range(total_images))
    print(f"{class_name}: {total_items_for_class} items")
# Out:
# Total items per class:
# class1: 150 items
# class2: 150 items
# class3: 150 items
# class4: 150 items
# class5: 150 items
# class6: 150 items
# class7: 150 items
# class8: 148 items
# class10: 149 items
# class10_1: 150 items

# %%
# Data for 50 images
images = [
# {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2},
# {'class1': 1, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1},
# {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1},
{'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1},
{'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 1},
{'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 1},
{'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 2},
{'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2},
{'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2},
{'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1},
{'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2},
{'class1': 1, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2},
{'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1},
{'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2},
{'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 2, 'class10_1': 2},
{'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 2},
{'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1},
# {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2},
# {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 1},
# {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 1},
# {'class1': 2, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 1, 'class10_1': 1},
# {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1},
# {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 2, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2},
# {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1},
# {'class1': 2, 'class2': 2, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 1, 'class6': 2, 'class7': 2, 'class8': 1, 'class10': 1, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 1, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 2, 'class2': 1, 'class3': 2, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 1, 'class8': 2, 'class10': 1, 'class10_1': 1},
# {'class1': 1, 'class2': 2, 'class3': 2, 'class4': 1, 'class5': 2, 'class6': 1, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 1},
# {'class1': 1, 'class2': 1, 'class3': 1, 'class4': 2, 'class5': 2, 'class6': 2, 'class7': 2, 'class8': 2, 'class10': 2, 'class10_1': 2},
# {'class1': 1, 'class2': 2, 'class3': 1, 'class4': 1, 'class5': 1, 'class6': 1, 'class7': 1, 'class8': 1, 'class10': 1, 'class10_1': 2}
]

# Initialize a dictionary to store the total count for each class
class_totals = {'class1': 0, 'class2': 0, 'class3': 0, 'class4': 0, 'class5': 0, 'class6': 0, 'class7': 0, 'class8': 0, 'class10': 0, 'class10_1': 0}

# Iterate through each image and add the class counts to the totals
for image in images:
    for class_name, count in image.items():
        class_totals[class_name] += count

# Print the total items for each class
for class_name, total in class_totals.items():
    print(f"{class_name}: {total} items")
# Out:
# class1: 38 items
# class2: 42 items
# class3: 40 items
# class4: 39 items
# class5: 41 items
# class6: 39 items
# class7: 42 items
# class8: 39 items
# class10: 37 items
# class10_1: 42 items
